# %% [markdown]
# #### BSc (Honours) in Computing in Software Development
# #### Emerging Technologies project 2020
# #### Grace Keane G00359990
# ***

# %% [markdown]
# ##### Printing out data and visualizing it in graphs

# %%
# Adapted from [1]
# Imports needed for Keras
# SAY WHAT ALL IMPORTS ARE FOR
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras as kr

# %%
# Reading in the CSV file
dataSet = pd.read_csv('powerproduction.csv')
# Printing out CSV data
print(dataSet)
# Out:
#       speed  power
# 0     0.000    0.0
# 1     0.125    0.0
# 2     0.150    0.0
# 3     0.225    0.0
# 4     0.275    0.0
# ..      ...    ...
# 495  24.775    0.0
# 496  24.850    0.0
# 497  24.875    0.0
# 498  24.950    0.0
# 499  25.000    0.0
#
# [500 rows x 2 columns]

# %%
# Printing out CSV (speed) file data as separate graph [2, 3]
# Speed graph
dataSet.plot(y='speed', x ='power', color='red')

plt.title('Speed value original data set')
plt.xlabel('power')
plt.ylabel('speed')
# Out:
# Text(0, 0.5, 'speed')

# %%
# Adapted from [4]

# Title
plt.title('Clearer view of original speed data')
# X-Axis
plt.xlabel('Speed')
# Y-Axis
plt.ylabel('Power')
# Visualising power graph using dots
plt.plot(dataSet.values[:,1], dataSet.values[:,0], 'k.', color='red')
plt.show()

# %%
# Printing out CSV (power) file data as separate graph [2, 3]

# Power graph
#plt.title('Speed value original data set')
dataSet.plot(x='speed', y='power', color='blue')

plt.title('Power value original data set')
plt.xlabel('speed')
plt.ylabel('power')
# Out:
# Text(0, 0.5, 'power')

# %%
# Adapted from [4]
# Title
plt.title('Clearer view of original power data')
# X-Axis
plt.xlabel('Power')
# Y-Axis
plt.ylabel('Speed')
# Visualising power graph using dots
plt.plot(dataSet.values[:,0], dataSet.values[:,1], 'k.', color='blue')
plt.show()

# %% [markdown]
# ***

# %% [markdown]
# ### Model 1 (Linear)

# %% [markdown]
# #### Training a model on the data set (powerproduction.csv)
# #### Linear model - single linear neuron

# %%
##### Single linear neuron structure diagram
from IPython.display import Image
Image(filename="Img/linear.png", width=500, height=500)

# %% [markdown]
# #### What is the liner model?
# #### Add brief description about linear neuron
# #### How does it work?

# %%
# Adapted from [4]
# Plot styles
plt.style.use('ggplot')

# Plot size
plt.rcParams['figure.figsize'] = (5, 5)

# %%
# df = data frame
x = dataSet[['speed']]
y = dataSet[['power']]

# %%
# Adapted from [5, 6, 7]
projectModel = kr.models.Sequential()
projectModel.add(kr.layers.Dense(1, input_shape=(1,), activation= "linear", kernel_initializer="ones", bias_initializer='zeros'))
# Compile the model
projectModel.compile(optimizer = "adam", loss='mean_squared_error')

# %% [markdown]
# ##### Getting the losses to be 700 & 1000 to see if there is any major differance.
# <b>Differance<b> = 30.4462

# %%
# epoch - speciefies how many times the linear algorithm will work 
# through the entire data set

# Adapter from [5, 6]
projectModel.fit(x, y, epochs = 700)
# Out:
# Epoch 1/700
# 16/16 [==============================] - 0s 4ms/step - loss: 2513.0327
# Epoch 2/700
# 16/16 [==============================] - 0s 2ms/step - loss: 2491.9690
# Epoch 3/700
# 16/16 [==============================] - 0s 1ms/step - loss: 2470.8718
# Epoch 4/700
# 16/16 [==============================] - 0s 1ms/step - loss: 2449.7495
# Epoch 5/700
# 16/16 [==============================] - 0s 2ms/step - loss: 2429.6086
# Epoch 6/700
# 16/16 [==============================] - 0s 2ms/step - loss: 2408.4609
# Epoch 7/700
# 16/16 [==============================] - 0s 1ms/step - loss: 2388.4087
# Epoch 8/700
# 16/16 [==============================] - 0s 1ms/step - loss: 2367.6770
# Epoch 9/700
# 16/16 [==============================] - 0s 2ms/step - loss: 2347.9954
# Epoch 10/700
# 16/16 [==============================] - 0s 2ms/step - loss: 2328.0164
# Epoch 11/700
# 16/16 [==============================] - 0s 2ms/step - loss: 2307.8599
# Epoch 12/700
# ...

# %%
projectModel.fit(x, y, epochs = 1000)
# Out:
# Epoch 1/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 505.6700
# Epoch 2/1000
# 16/16 [==============================] - 0s 3ms/step - loss: 505.5654
# Epoch 3/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 505.5331
# Epoch 4/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 505.4696
# Epoch 5/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 505.4020
# Epoch 6/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 505.3456
# Epoch 7/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 505.3929
# Epoch 8/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 505.3142
# Epoch 9/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 505.1554
# Epoch 10/1000
# 16/16 [==============================] - 0s 1ms/step - loss: 505.1133
# Epoch 11/1000
# 16/16 [==============================] - 0s 2ms/step - loss: 505.0731
# Epoch 12/1000
# ...

# %%
# Manual predictions
projectModel.predict([30.0, 70.0, 80.0, 100.0])
# Out:
# array([[129.35405],
#        [313.39294],
#        [359.40265],
#        [451.4221 ]], dtype=float32)

# %%
# Adapted from [8]
# Plotted the linear model
# Auto generated predictions
plt.plot(x, y, ".", color="black", label='Actual Data')
plt.plot(x, projectModel.predict(x), linewidth=2, label='Prediction')
# X-Axis
plt.xlabel('Speed')
# Y-Axis
plt.ylabel('Power')
plt.legend()

# %%
# How does my code work

# %% [markdown]
# ***

# %% [markdown]
# ### Model 2 (Sigmoid)

# %% [markdown]
# #### Training a model on the data set (powerproduction.csv)
# #### Sigmoid model

# %%
##### Single linear neuron structure diagram
from IPython.display import Image
Image(filename="Img/sigmoid.png", width=500, height=500)

# %%
# How does the model work?
# Put descriptions

# %% [markdown]
# #### Testing Sigmoid model on original data

# %%
# Adapted from [5, 6, 7]
projectModel = kr.models.Sequential()
projectModel.add(kr.layers.Dense(70, input_shape=(1,), activation= "sigmoid", kernel_initializer="glorot_uniform", bias_initializer='glorot_uniform'))
# Compile the model
projectModel.add(kr.layers.Dense(1, input_shape=(1,), activation= "linear", kernel_initializer="glorot_uniform", bias_initializer='glorot_uniform'))
projectModel.add(kr.layers.Dense(1, input_shape=(1,), activation= "linear", kernel_initializer="glorot_uniform", bias_initializer='glorot_uniform'))

# Compile the model
projectModel.compile(kr.optimizers.Adam(lr=0.001), loss='mean_squared_error')

# %%
projectModel.fit(x, y, epochs = 700)
# Out:
# Epoch 1/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3785.6621
# Epoch 2/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3740.2939
# Epoch 3/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3691.3574
# Epoch 4/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3635.1296
# Epoch 5/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3570.9412
# Epoch 6/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3498.8274
# Epoch 7/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3416.8342
# Epoch 8/700
# 16/16 [==============================] - ETA: 0s - loss: 2694.08 - 0s 2ms/step - loss: 3322.1960
# Epoch 9/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3218.9241
# Epoch 10/700
# 16/16 [==============================] - 0s 2ms/step - loss: 3110.8418
# Epoch 11/700
# 16/16 [==============================] - 0s 1ms/step - loss: 2997.2305
# Epoch 12/700
# ...

# %%
# Manual predictions
projectModel.predict([6.732, 10.185, 19.645, 24.750])
# Out:
# array([[ 3.3673868],
#        [24.713785 ],
#        [90.697556 ],
#        [93.31339  ]], dtype=float32)

# %%
# Adapted from [8]
# Plotted the linear model
# Auto generated predictions
plt.plot(x, y, ".", color="black", label='Actual Data')
plt.plot(x, projectModel.predict(x), linewidth=2, label='Prediction')
# X-Axis
plt.xlabel('Speed')
# Y-Axis
plt.ylabel('Power')
plt.legend()

# %% [markdown]
# ### Model 3
#
# #### Testing model on data with 0's takes out
#
# #### why did you take the values out? explain...

# %%
# Reading in the CSV file
dataSet = pd.read_csv('0ValuesDeleted.csv')
# Printing out CSV data
print(dataSet)
# Out:
#       speed    power
# 0     0.325    4.331
# 1     0.400    5.186
# 2     0.450    3.826
# 3     0.501    1.048
# 4     0.526    5.553
# ..      ...      ...
# 446  24.249  103.700
# 447  24.299   93.694
# 448  24.349   93.078
# 449  24.374   98.223
# 450  24.399   95.117
#
# [451 rows x 2 columns]

# %%
# Adapted from [5, 6, 7]
projectModel = kr.models.Sequential()
# Compile the model
# Sigmoid
projectModel.add(kr.layers.Dense(1, input_shape=(1,), activation= "sigmoid", kernel_initializer="glorot_uniform", bias_initializer='glorot_uniform'))
# Linear (x2)
projectModel.add(kr.layers.Dense(1, input_shape=(1,), activation= "linear", kernel_initializer="glorot_uniform", bias_initializer='glorot_uniform'))
projectModel.add(kr.layers.Dense(1, input_shape=(1,), activation= "linear", kernel_initializer="glorot_uniform", bias_initializer='glorot_uniform'))
# Compile the model
projectModel.compile(kr.optimizers.Adam(lr=0.001), loss='mean_squared_error')

# %%
# Training the model with the x and y values and setting iteration to 900
projectModel.fit(dataSet['speed'], dataSet['power'], epochs=900)
# Out:
# Epoch 1/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4509.0605
# Epoch 2/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4505.5732
# Epoch 3/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4501.9438
# Epoch 4/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4498.2842
# Epoch 5/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4494.4360
# Epoch 6/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4490.4258
# Epoch 7/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4486.3584
# Epoch 8/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4481.9346
# Epoch 9/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4477.3848
# Epoch 10/900
# 15/15 [==============================] - 0s 2ms/step - loss: 4472.6953
# Epoch 11/900
# 15/15 [==============================] - 0s 1ms/step - loss: 4467.9009
# Epoch 12/900
# ...

# %%
# Manual predictions
projectModel.predict([4.0, 20.0, 23.0, 11.0])
# Out:
# array([[ 5.0261827],
#        [97.94644  ],
#        [98.99692  ],
#        [27.503912 ]], dtype=float32)

# %%
# Adapted from [8]
# Plotted the linear model
# Auto generated predictions
plt.plot(x, y, ".", color="black", label='Actual Data')
plt.plot(x, projectModel.predict(x), linewidth=2, label='Prediction')
# X-Axis
plt.xlabel('Speed')
# Y-Axis
plt.ylabel('Power')
plt.legend()

# %% [markdown]
# ##### Explanations

# %%
# How does my code work

# %% [markdown]
# ##### Accuracy

# %% [markdown]
# ***

# %% [markdown]
# ##### Referances
#
# [1] Keras; Simple MNIST convnet;
#
# https://keras.io/examples/vision/mnist_convnet/
#
# [2] CodeSpeedy; How to change line color in matplotlib;
#
# https://www.codespeedy.com/how-to-change-line-color-in-matplotlib/
#
# [3] GeeksforGeeks; Graph Plotting in Python | Set 1;
#
# https://www.geeksforgeeks.org/graph-plotting-in-python-set-1/
#
# [4] GitHub; Regression in Python lab;
#
# https://github.com/ianmcloughlin/jupyter-teaching-notebooks/blob/master/regression.ipynb
#
# [5] Microsoft Stream; A keras example;
#
# https://web.microsoftstream.com/video/bf7aaf56-d65f-47fb-aec9-e0c2af49534a
#
# [6] Keras; Introduction to Keras for Engineers;
#
# https://keras.io/getting_started/intro_to_keras_for_engineers/
#
# [7] Microsoft Stream; Neurons in keras;
#
# https://web.microsoftstream.com/video/7ffcdaef-72ef-4ad1-96c3-acc92f8e184d?list=studio
#
# [8] TensorFlow; Linear regression;
#
# https://www.tensorflow.org/tutorials/keras/regression

# %% [markdown]
# ***
#
# <b>End<b>
#
# ***
