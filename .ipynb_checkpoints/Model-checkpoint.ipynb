# %% [markdown]
# #### BSc (Honours) in Computing in Software Development
# #### Emerging Technologies project 2020
# #### Grace Keane G00359990
# ***

# %% [markdown]
# ##### Training a model of the data set

# %%
# Adapted from [1]
# Imports needed for Keras
# SAY WHAT ALL IMPORTS ARE FOR
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow.keras as kr

# %%
# Reading in the CSV file
df = pd.read_csv('Outputs.csv')
# Printing out CSV data
print(df)
# Out:
#       speed  power
# 0     0.000    0.0
# 1     0.125    0.0
# 2     0.150    0.0
# 3     0.225    0.0
# 4     0.275    0.0
# ..      ...    ...
# 495  24.775    0.0
# 496  24.850    0.0
# 497  24.875    0.0
# 498  24.950    0.0
# 499  25.000    0.0
#
# [500 rows x 2 columns]

# %%
# Printing out CSV (speed) file data as separate graph [2, 3]
# Speed graph
df.plot(y='speed', x ='power', color='red')

plt.title('Speed value original data set')
plt.xlabel('power')
plt.ylabel('speed')
# Out:
# Text(0, 0.5, 'speed')

# %%
# Printing out CSV (power) file data as separate graph [2, 3]

# Power graph
#plt.title('Speed value original data set')
df.plot(x='speed', y='power', color='blue')

plt.title('Power value original data set')
plt.xlabel('speed')
plt.ylabel('power')
# Out:
# Text(0, 0.5, 'power')

# %%
# Reading in dataset
dataset = pd.read_csv("Outputs.csv")

# Adapted from [4]
# Title
plt.title('Clearer view of data altogether')
# X-Axis
plt.xlabel('Speed')
# Y-Axis
plt.ylabel('Power')
# Visualising graph using dots
plt.plot(dataset.values[:,0], dataset.values[:,1], 'k.')
plt.show()

# %%
# Graph predictions go here

# %% [markdown]
# ##### Explanations

# %% [markdown]
# ##### Accuracy

# %% [markdown]
# ##### Referances
#
# [1] Keras; Simple MNIST convnet;
#
# https://keras.io/examples/vision/mnist_convnet/
#
# [2] CodeSpeedy; How to change line color in matplotlib;
#
# https://www.codespeedy.com/how-to-change-line-color-in-matplotlib/
#
# [3] GeeksforGeeks; Graph Plotting in Python | Set 1;
#
# https://www.geeksforgeeks.org/graph-plotting-in-python-set-1/
#
# [4] GitHub; Regression in Python lab;
#
# https://github.com/ianmcloughlin/jupyter-teaching-notebooks/blob/master/regression.ipynb
#
# [5] Microsoft Stream; A keras example;
#
# https://web.microsoftstream.com/video/bf7aaf56-d65f-47fb-aec9-e0c2af49534a

# %% [markdown]
# ***
#
# <b>End<b>
#
# ***
